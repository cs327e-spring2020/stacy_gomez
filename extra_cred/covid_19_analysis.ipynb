# %% [markdown]
# ## covid_19_analysis

# %% [markdown]
# #### This query lists the states and confirmed number of cases in descending order by total confirmed cases in the month of march

# %%
# %%bigquery
# select distinct state, sum(confirmed) as confirmed
# from covid_19_modeled.event e join covid_19_modeled.location l
# on e.location_id = l.id
# where last_update BETWEEN '2020-03-01 00:00:00' AND '2020-03-31 23:59:59'
# group by state
# order by confirmed desc
# Out:
#               state  confirmed
# 0                NY     279233
# 1                WA      27165
# 2                IL      24737
# 3                NJ      23124
# 4                CA      20987
# ..              ...        ...
# 97               WI          1
# 98               MO          1
# 99               LA          1
# 100       Recovered          0
# 101  American Samoa          0
#
# [102 rows x 2 columns]

# %% [markdown]
# #### This query totals the number of confirmed cases and recoveries from the top 5 states for the month of march

# %%
# %%bigquery
# select state, sum(confirmed) as confirmed, sum(recovered) as recovered
# from covid_19_modeled.event e join covid_19_modeled.location l
# on e.location_id = l.id
# where state in ('NY', 'WA', 'IL', 'NJ', 'CA') and last_update BETWEEN '2020-03-01 00:00:00' AND '2020-03-31 23:59:59'
# group by state
# order by confirmed desc
# Out:
#   state  confirmed  recovered
# 0    NY     279233          0
# 1    WA      27165          8
# 2    IL      24737         16
# 3    NJ      23124          2
# 4    CA      20987         40

# %% [markdown]
# #### This query lists the states and confirmed number of cases in descending order by total confirmed cases in the month of april

# %%
# %%bigquery
# select distinct state, sum(confirmed) as confirmed
# from covid_19_modeled.event e join covid_19_modeled.location l
# on e.location_id = l.id
# where last_update BETWEEN '2020-04-01 00:00:00' AND '2020-04-30 23:59:59'
# group by state
# order by confirmed desc
# Out:
#                        state  confirmed
# 0                         NY    3457515
# 1                         IL     522698
# 2                         MI     341424
# 3                         CA     338028
# 4                         NJ     308286
# 5                         FL     224579
# 6                         PA     221628
# 7                         MA     206637
# 8                         CT     193592
# 9                         LA     157019
# 10                        WA     130970
# 11                        TX     110240
# 12                        IN      94101
# 13                        MD      78630
# 14                        NV      73482
# 15                        RI      70990
# 16      District of Columbia      66631
# 17                        AZ      64773
# 18                        MO      53840
# 19                        WI      53792
# 20                        GA      51341
# 21                        CO      44721
# ...

# %% [markdown]
# #### This query totals the number of confirmed cases and recoveries from the top 5 states for the month of april

# %%
# %%bigquery
# select state, sum(confirmed) as confirmed, sum(recovered) as recovered
# from covid_19_modeled.event e join covid_19_modeled.location l
# on e.location_id = l.id
# where state in ('NY', 'IL', 'MI', 'CA', 'NJ') and last_update BETWEEN '2020-04-01 00:00:00' AND '2020-04-30 23:59:59'
# group by state
# order by confirmed desc
# Out:
#   state  confirmed  recovered
# 0    NY    3457515          0
# 1    IL     522698          0
# 2    MI     341424          0
# 3    CA     338028          0
# 4    NJ     308286          0

# %% [markdown]
# ## Create Views of queries found above

# %%
# %%bigquery
# create or replace view covid_19_modeled.v_top_state_march_cases as
# select distinct state, sum(confirmed) as confirmed
# from `extracredit-276620.covid_19_modeled.event` e join `extracredit-276620.covid_19_modeled.location` l
# on e.location_id = l.id
# where last_update BETWEEN '2020-03-01 00:00:00' AND '2020-03-31 23:59:59'
# group by state
# order by confirmed desc
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# create or replace view covid_19_modeled.v_top_state_march_cases_and_recoveries as
# select state, sum(confirmed) as confirmed, sum(recovered) as recovered
# from `extracredit-276620.covid_19_modeled.event` e join `extracredit-276620.covid_19_modeled.location` l
# on e.location_id = l.id
# where state in ('NY', 'WA', 'IL', 'NJ', 'CA') and last_update BETWEEN '2020-03-01 00:00:00' AND '2020-03-31 23:59:59'
# group by state
# order by confirmed desc
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# create or replace view covid_19_modeled.v_top_state_april_cases as
# select distinct state, sum(confirmed) as confirmed
# from `extracredit-276620.covid_19_modeled.event` e join `extracredit-276620.covid_19_modeled.location` l
# on e.location_id = l.id
# where last_update BETWEEN '2020-04-01 00:00:00' AND '2020-04-30 23:59:59'
# group by state
# order by confirmed desc
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# create or replace view covid_19_modeled.v_top_state_april_cases_and_recoveries as
# select state, sum(confirmed) as confirmed, sum(recovered) as recovered
# from `extracredit-276620.covid_19_modeled.event` e join `extracredit-276620.covid_19_modeled.location` l
# on e.location_id = l.id
# where state in ('NY', 'IL', 'MI', 'CA', 'NJ') and last_update BETWEEN '2020-04-01 00:00:00' AND '2020-04-30 23:59:59'
# group by state
# order by confirmed desc
# Out:
# Empty DataFrame
# Columns: []
# Index: []
